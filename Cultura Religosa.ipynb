# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./Formulário sem título.csv")

# %%
data.describe()
# Out:
#                Carimbo de data/hora Qual o seu gênero?     Qual sua idade?  \
# count                            71                 71                  71
# unique                           71                  4                   3
# top     2022/11/07 9:06:12 PM GMT-3          Homem Cis  Entre 18 e 25 anos
# freq                              1                 42                  49
#
#        Pratica algum esporte? Descreva qual, ou quais esportes pratica.  \
# count                      71                                        60
# unique                      2                                        43
# top                       Sim                                  Futebol
# freq                       60                                         7
#
#        Quantos atletas transgênero você conhece?  \
# count                                         60
# unique                                         4
# top                                       Nenhum
# ...

# %%
data = data.drop(columns=["Deixe seu comentário, opnião ou sugestão em relação ao tema."])
for col in data:

    sns.histplot(data=data, x=col).set_title(f"{col}")
    plt.show()
    plt.xticks(rotation=90)
