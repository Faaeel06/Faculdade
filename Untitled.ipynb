# %%
A = "Correu foi seu dia?"

# %%
for i in range(0, 101):
    
    print(A)
# Out:
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# Correu foi seu dia?
# ...
